# %% [markdown]
# Problem 3.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("drug_consumption_data.csv")
drugs_5 = ["LSD", "Mushrooms", "Cannabis", "Caff", "Coke"]
df_new = df[drugs_5 ]
df_new = df_new.replace("CL0", 0)
df_new = df_new.replace("CL1", 1)
df_new = df_new.replace("CL2", 2)
df_new = df_new.replace("CL3", 3)
df_new = df_new.replace("CL4", 4)
df_new = df_new.replace("CL5", 5)
df_new = df_new.replace("CL6", 6)
df_new = df_new.astype(float)
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_new)
plt.gca().set_yticks([0,1,2,3,4,5,6])
plt.gca().set_yticklabels(["CL0","CL1","CL2","CL3","CL4","CL5","CL6"])
plt.title("Rating for the selected Drugs")
plt.show()

# %% [markdown]
# Problem 3.2

# %%
drugs_1 = ['Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff']


fig, axes = plt.subplots(1, len(drugs_1), figsize=(15, 5), sharey=True)

for i, drugs_1 in enumerate(drugs_1):
    sns.countplot(ax=axes[i], data=df, x=drugs_1, hue="Gender")
    axes[i].set_xlabel(drugs_1)

# plt.tight_layout()
plt.show()

# %%
drugs_2= ['Cannabis', 'Choc', 'Coke', 'Crack','Ecstasy']

fig, axes = plt.subplots(1, len(drugs_2), figsize=(15, 5), sharey=True)

for i, drugs_2 in enumerate(drugs_2):
    sns.countplot(ax=axes[i], data=df, x=drugs_2, hue="Gender")
    axes[i].set_xlabel(drugs_2)

# plt.tight_layout()
plt.show()

# %%
drugs_3= ['Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth']

fig, axes = plt.subplots(1, len(drugs_3), figsize=(15, 5), sharey=True)

for i, drugs_3 in enumerate(drugs_3):
    sns.countplot(ax=axes[i], data=df, x=drugs_3, hue="Gender")
    axes[i].set_xlabel(drugs_3)

# plt.tight_layout()
plt.show()

# %%
drugs_4= ['Mushrooms','Nicotine', 'Semer', 'VSA']
fig, axes = plt.subplots(1, len(drugs_4), figsize=(15, 5), sharey=True)

for i, drugs_4 in enumerate(drugs_4):
    sns.countplot(ax=axes[i], data=df, x=drugs_4, hue="Gender")
    axes[i].set_xlabel(drugs_4)

# plt.tight_layout()
plt.show()

# %% [markdown]
# 3.3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("drug_consumption_data.csv")

# %%
df
# Out:
#         ID    Age Gender                                          Education  \
# 0        2  25-34      M                                   Doctorate degree
# 1        3  35-44      M                  Professional certificate/ diploma
# 2        4  18-24      F                                     Masters degree
# 3        5  35-44      F                                   Doctorate degree
# 4        6    65+      F                            Left school at 18 years
# ...    ...    ...    ...                                                ...
# 1879  1884  18-24      F  Some college or university, no certificate or ...
# 1880  1885  18-24      M  Some college or university, no certificate or ...
# 1881  1886  25-34      F                                  University degree
# 1882  1887  18-24      F  Some college or university, no certificate or ...
# 1883  1888  18-24      M  Some college or university, no certificate or ...
#
# ...

# %%
df = df.replace("CL0", 0)
df = df.replace("CL1", 1)
df = df.replace("CL2", 2)
df = df.replace("CL3", 3)
df = df.replace("CL4", 4)
df = df.replace("CL5", 5)
df = df.replace("CL6", 6)
df = df.astype(float)

# %%
corr = df.corr()
corr
# Out:
#                  ID    Nscore    Escore    Oscore    AScore    Cscore  \
# ID         1.000000  0.018943 -0.047532  0.173181 -0.029658 -0.072157
# Nscore     0.018943  1.000000 -0.431004  0.010275 -0.216865 -0.391098
# Escore    -0.047532 -0.431004  1.000000  0.245142  0.157103  0.308049
# Oscore     0.173181  0.010275  0.245142  1.000000  0.038242 -0.056818
# AScore    -0.029658 -0.216865  0.157103  0.038242  1.000000  0.247534
# Cscore    -0.072157 -0.391098  0.308049 -0.056818  0.247534  1.000000
# Impulsive  0.119543  0.174445  0.114091  0.277468 -0.229860 -0.335139
# SS         0.164955  0.080225  0.209858  0.421535 -0.208787 -0.229133
# Alcohol   -0.020045 -0.001927  0.092397  0.032800 -0.021677 -0.000202
# Amphet     0.169105  0.131067 -0.040987  0.221259 -0.148726 -0.236242
# Amyl      -0.030257  0.033416  0.030029  0.060345 -0.096366 -0.117815
# Benzos     0.157334  0.272186 -0.103366  0.201446 -0.164413 -0.206386
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
plt.xticks(fontsize=12,rotation=70)
plt.yticks(fontsize=12)
plt.title("Heatmap for drugs and the 12 personality measurement attributes")
plt.show()

# %% [markdown]
# 3.4

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("drug_consumption_data.csv")
df = df.replace("CL0", 0)
df = df.replace("CL1", 1)
df = df.replace("CL2", 2)
df = df.replace("CL3", 3)
df = df.replace("CL4", 4)
df = df.replace("CL5", 5)
df = df.replace("CL6", 6)

# %%
df
# Out:
#         ID    Age Gender                                          Education  \
# 0        2  25-34      M                                   Doctorate degree
# 1        3  35-44      M                  Professional certificate/ diploma
# 2        4  18-24      F                                     Masters degree
# 3        5  35-44      F                                   Doctorate degree
# 4        6    65+      F                            Left school at 18 years
# ...    ...    ...    ...                                                ...
# 1879  1884  18-24      F  Some college or university, no certificate or ...
# 1880  1885  18-24      M  Some college or university, no certificate or ...
# 1881  1886  25-34      F                                  University degree
# 1882  1887  18-24      F  Some college or university, no certificate or ...
# 1883  1888  18-24      M  Some college or university, no certificate or ...
#
# ...

# %%
drugs_corr_df = df.drop('ID', axis = 1)
drugs_corr_df.head(10)
# Out:
#      Age Gender                          Education Country Ethnicity   Nscore  \
# 0  25-34      M                   Doctorate degree      UK     White -0.67825
# 1  35-44      M  Professional certificate/ diploma      UK     White -0.46725
# 2  18-24      F                     Masters degree      UK     White -0.14882
# 3  35-44      F                   Doctorate degree      UK     White  0.73545
# 4    65+      F            Left school at 18 years  Canada     White -0.67825
# 5  45-54      M                     Masters degree     USA     White -0.46725
# 6  35-44      M            Left school at 16 years      UK     White -1.32828
# 7  35-44      F  Professional certificate/ diploma  Canada     White  0.62967
# 8  55-64      M                     Masters degree      UK     White -0.24649
# 9  25-34      F                  University degree      UK     White -1.05308
#
#     Escore   Oscore   AScore   Cscore  ...  Ecstasy  Heroin Ketamine Legalh  \
# ...

# %%
drugs_corr_df = drugs_corr_df.replace("CL0", 0)
drugs_corr_df = drugs_corr_df.replace("CL1", 1)
drugs_corr_df = drugs_corr_df.replace("CL2", 2)
drugs_corr_df = drugs_corr_df.replace("CL3", 3)
drugs_corr_df = drugs_corr_df.replace("CL4", 4)
drugs_corr_df = drugs_corr_df.replace("CL5", 5)
drugs_corr_df = drugs_corr_df.replace("CL6", 6)

# %%
drugs_corr_df = drugs_corr_df[['Nscore', 'Escore', 'Oscore', 'AScore', 'Cscore', 'Impulsive', 'SS', 
                              'Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 
                               'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']]
drugs = ['Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 
         'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']
drugs_corr = drugs_corr_df.corr()
drugs_corr = drugs_corr.drop(drugs, axis = 0)
drugs_corr
# Out:
#              Nscore    Escore    Oscore    AScore    Cscore  Impulsive  \
# Nscore     1.000000 -0.431004  0.010275 -0.216865 -0.391098   0.174445
# Escore    -0.431004  1.000000  0.245142  0.157103  0.308049   0.114091
# Oscore     0.010275  0.245142  1.000000  0.038242 -0.056818   0.277468
# AScore    -0.216865  0.157103  0.038242  1.000000  0.247534  -0.229860
# Cscore    -0.391098  0.308049 -0.056818  0.247534  1.000000  -0.335139
# Impulsive  0.174445  0.114091  0.277468 -0.229860 -0.335139   1.000000
# SS         0.080225  0.209858  0.421535 -0.208787 -0.229133   0.623223
#
#                  SS   Alcohol    Amphet      Amyl  ...   Ecstasy    Heroin  \
# Nscore     0.080225 -0.001927  0.131067  0.033416  ...  0.070094  0.172755
# Escore     0.209858  0.092397 -0.040987  0.030029  ...  0.078598 -0.080119
# Oscore     0.421535  0.032800  0.221259  0.060345  ...  0.296135  0.134098
# AScore    -0.208787 -0.021677 -0.148726 -0.096366  ... -0.114984 -0.170107
# ...

# %%
for drug in drugs:
    print(drug)
    two_attr_corr = list(drugs_corr[drug].abs().sort_values(ascending = False).index[:2])
    print(two_attr_corr)
    sns.boxplot(x=drugs_consume_df[drug], y=drugs_consume_df[two_attr_corr[0]], palette = 'viridis') 
    plt.figure(figsize=(20,11))
    plt.show()
    sns.boxplot(y=drugs_consume_df[two_attr_corr[1]], x=drugs_consume_df[drug], palette = 'rocket')
    plt.figure(figsize=(20,11))
    plt.show()
# Out:
# Alcohol
# ['SS', 'Escore']
# Amphet
# ['SS', 'Impulsive']
# Amyl
# ['SS', 'Impulsive']
# Benzos
# ['Nscore', 'SS']
# Caff
# ['Escore', 'SS']
# Cannabis
# ['SS', 'Oscore']
# Choc
# ['SS', 'AScore']
# Coke
# ['SS', 'Impulsive']
# Crack
# ['SS', 'Impulsive']
# Ecstasy
# ['SS', 'Oscore']
# Heroin
# ['SS', 'Impulsive']
# Ketamine
# ['SS', 'Oscore']
# Legalh
# ['SS', 'Oscore']
# LSD
# ['Oscore', 'SS']
# Meth
# ['SS', 'Cscore']
# Mushrooms
# ['SS', 'Oscore']
# Nicotine
# ['SS', 'Impulsive']
# Semer
# ['SS', 'Oscore']
# VSA
# ['SS', 'Impulsive']
